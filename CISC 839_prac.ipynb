# %% [raw]
# # Each data point includes date/time, the type of boarding, bus and route number, and latitude/longitude where the boarding was recorded (note that around 8% of these were on buses with malfunctioning GPS antennae, and have the boarding coordinates recorded as 0,0). One note – you will see references to Routes 8 and 13 in the data. These routes do not have public timetables; these are extra buses to help service peak demand in certain areas of the City (primarily, the Union Street corridor between St. Lawrence College and Downtown).

# %%
import pandas as pd
import gmplot

# %%
df=pd.read_excel("/Users/aimee/Desktop/CISC 839/assignment/assignment1/Transit Data - October.xlsx")

# %%
df
# Out:
#              Date                Time        Class                Operation  \
# 0      2017-10-01 1900-01-01 01:43:03       QUEENS               Exact Fare
# 1      2017-10-01 1900-01-01 01:43:08       QUEENS               Exact Fare
# 2      2017-10-01 1900-01-01 01:58:13        ADULT   Pass (Multi-ride card)
# 3      2017-10-01 1900-01-01 01:58:25       QUEENS               Exact Fare
# 4      2017-10-01 1900-01-01 01:58:27       QUEENS               Exact Fare
# ...           ...                 ...          ...                      ...
# 704534 2017-10-01 1900-01-01 17:07:13       QUEENS               Exact Fare
# 704535 2017-10-01 1900-01-01 17:07:22       QUEENS               Exact Fare
# 704536 2017-10-01 1900-01-01 17:07:31  ST LAWRENCE               Exact Fare
# 704537 2017-10-01 1900-01-01 17:08:47       QUEENS               Exact Fare
# 704538 2017-10-01 1900-01-01 17:09:41        ADULT  Rides (Multi-ride card)
#
#          Bus  Route   Latitude  Longitude
# ...

# %%
data=df[df['Latitude'] != 0]

# %%
data.describe()
# Out:
#                  Bus          Route       Latitude      Longitude
# count  648786.000000  648786.000000  648786.000000  648786.000000
# mean     1264.482960     246.043791      44.459798     -76.671798
# std       300.223573     289.822994       6.873336       5.960070
# min       315.000000       1.000000       0.001280    -255.426092
# 25%      1048.000000       3.000000      44.227882     -76.533590
# 50%      1361.000000      15.000000      44.235697     -76.507990
# 75%      1480.000000     502.000000      44.250848     -76.492228
# max      1689.000000     701.000000     255.426092      -3.051285

# %%
ax = data.plot.scatter(x="Route", y="Class", color="DarkBlue", label="Group 1")

# %%
data_Queen=data[data['Class'] == "QUEENS"]

# %%
data_Queen
# Out:
#              Date                Time   Class   Operation   Bus  Route  \
# 0      2017-10-01 1900-01-01 01:43:03  QUEENS  Exact Fare   620     17
# 1      2017-10-01 1900-01-01 01:43:08  QUEENS  Exact Fare   620     17
# 3      2017-10-01 1900-01-01 01:58:25  QUEENS  Exact Fare   620     17
# 4      2017-10-01 1900-01-01 01:58:27  QUEENS  Exact Fare   620     17
# 5      2017-10-01 1900-01-01 01:58:30  QUEENS  Exact Fare   620     17
# ...           ...                 ...     ...         ...   ...    ...
# 704531 2017-10-01 1900-01-01 17:06:51  QUEENS  Exact Fare  1362    701
# 704533 2017-10-01 1900-01-01 17:07:03  QUEENS  Exact Fare  1362    701
# 704534 2017-10-01 1900-01-01 17:07:13  QUEENS  Exact Fare  1362    701
# 704535 2017-10-01 1900-01-01 17:07:22  QUEENS  Exact Fare  1362    701
# 704537 2017-10-01 1900-01-01 17:08:47  QUEENS  Exact Fare  1257     18
#
#          Latitude  Longitude
# 0       44.227860 -76.496938
# 1       44.227860 -76.496938
# ...

# %%
data_Queen_17=data_Queen[data_Queen['Route'] == 17]

# %%
gmap = gmplot.GoogleMapPlotter.from_geocode( "Kingston, Canada", zoom = 13, apikey ='AIzaSyDuTXaWuBFqdvOlMAkrVVLpQTqNc_QC7o0')

# %%
gmap.scatter(data_Queen_17['Latitude'], data_Queen_17['Longitude'], "red", size = 20, marker = False )

# %%
gmap.draw( "17.html" )

# %%
'''
data_Queen_502=data_Queen[data_Queen['Route'] == 502]
gmplot.GoogleMapPlotter.from_geocode( "Kingston, Canada", zoom = 13, apikey ='AIzaSyDuTXaWuBFqdvOlMAkrVVLpQTqNc_QC7o0')
gmap.scatter(data_Queen_502['Latitude'], data_Queen_502['Longitude'], "green", size = 20, marker = False )
gmap.draw( "502.html" )
'''
# Out:
# '\ndata_Queen_502=data_Queen[data_Queen[\'Route\'] == 502]\ngmplot.GoogleMapPlotter.from_geocode( "Kingston, Canada", zoom = 13, apikey =\'AIzaSyDuTXaWuBFqdvOlMAkrVVLpQTqNc_QC7o0\')\ngmap.scatter(data_Queen_502[\'Latitude\'], data_Queen_502[\'Longitude\'], "green", size = 20, marker = False )\ngmap.draw( "502.html" )\n'

# %%
data_Queen_3=data_Queen[data_Queen['Route'] == 3]
gmplot.GoogleMapPlotter.from_geocode( "Kingston, Canada", zoom = 13, apikey ='AIzaSyDuTXaWuBFqdvOlMAkrVVLpQTqNc_QC7o0')
gmap.scatter(data_Queen_3['Latitude'], data_Queen_3['Longitude'], "bule", size = 20, marker = False )
gmap.draw( "3.html" )
# Out:
# /Users/aimee/Library/Python/3.8/lib/python/site-packages/gmplot/color.py:194: UserWarning: Color 'bule' isn't supported.
#   warnings.warn("Color '%s' isn't supported." % color)

# %%
data_Queen_1=data_Queen[data_Queen['Route'] == 1]
gmplot.GoogleMapPlotter.from_geocode( "Kingston, Canada", zoom = 13, apikey ='AIzaSyDuTXaWuBFqdvOlMAkrVVLpQTqNc_QC7o0')
gmap.scatter(data_Queen_1['Latitude'], data_Queen_1['Longitude'], "yellow", size = 20, marker = False )
gmap.draw( "1.html" )
